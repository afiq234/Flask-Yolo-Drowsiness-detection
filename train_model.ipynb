# %%
import uuid
import os
import time
import cv2

# %%
img_path = os.path.join('data', 'images')
labels = ['awake', 'drowsy']
num_imgs = 20

# %%
for label in labels:
    print(label)
    for img_num in range(num_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(img_path, label+'.'+str(uuid.uuid1()) + '.jpg')
        print(imgname)
# Out:
# awake
# ...
# data\images\awake.690d1f70-b878-11ef-b664-48e7daab4808.jpg
# ...
# data\images\awake.690d1f71-b878-11ef-8036-48e7daab4808.jpg
# ...
# data\images\awake.690d1f72-b878-11ef-9c06-48e7daab4808.jpg
# ...
# data\images\awake.690d1f73-b878-11ef-9d85-48e7daab4808.jpg
# ...
# data\images\awake.690d4692-b878-11ef-84a0-48e7daab4808.jpg
# ...
# data\images\awake.690d4693-b878-11ef-90aa-48e7daab4808.jpg
# ...
# data\images\awake.690d4694-b878-11ef-bcad-48e7daab4808.jpg
# ...
# data\images\awake.690d4695-b878-11ef-a090-48e7daab4808.jpg
# ...
# data\images\awake.690d4696-b878-11ef-97c9-48e7daab4808.jpg
# ...
# data\images\awake.690d4697-b878-11ef-a43a-48e7daab4808.jpg
# ...
# data\images\awake.690d4698-b878-11ef-8a5e-48e7daab4808.jpg
# ...
# data\images\awake.690d4699-b878-11ef-bddf-48e7daab4808.jpg
# ...
# data\images\awake.690d469a-b878-11ef-85dc-48e7daab4808.jpg
# ...
# data\images\awake.690d469b-b878-11ef-9282-48e7daab4808.jpg
# ...
# data\images\awake.690d469c-b878-11ef-b979-48e7daab4808.jpg
# ...
# data\images\awake.690d469d-b878-11ef-8be9-48e7daab4808.jpg
# ...

# %%
# %pip install opencv-python
import cv2

cap = cv2.VideoCapture(0)
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)

    for img_num in range(num_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))

        ret , frame = cap.read()

        imgname = os.path.join(img_path, label+'.'+str(uuid.uuid1())+'.jpg')
        cv2.imwrite(imgname, frame)
        cv2.imshow('Image collection', frame)
        time.sleep(2)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(num_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(img_path, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\awake.1b9b4ae1-a654-11ef-9520-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4ae2-a654-11ef-96b0-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4ae3-a654-11ef-ac9d-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4ae4-a654-11ef-8295-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4ae5-a654-11ef-a4a0-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4ae6-a654-11ef-9d7f-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4ae7-a654-11ef-b15f-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4ae8-a654-11ef-bf99-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4ae9-a654-11ef-96a9-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4aea-a654-11ef-bebc-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4aeb-a654-11ef-8126-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4aec-a654-11ef-9552-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4aed-a654-11ef-9f50-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4aee-a654-11ef-b48b-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4aef-a654-11ef-b584-48e7daab4808.jpg
# ...
# data\images\awake.1b9b4af0-a654-11ef-bb34-48e7daab4808.jpg
# ...

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.9 MB 660.6 kB/s eta 0:00:11
#    - -------------------------------------- 0.2/6.9 MB 2.1 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/6.9 MB 4.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/6.9 MB 5.7 MB/s eta 0:00:02
#    -------- ------------------------------- 1.5/6.9 MB 6.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.7/6.9 MB 6.5 MB/s eta 0:00:01
#    ------------ --------------------------- 2.2/6.9 MB 7.0 MB/s eta 0:00:01
#    --------------- ------------------------ 2.7/6.9 MB 7.4 MB/s eta 0:00:01
#    ------------------ --------------------- 3.2/6.9 MB 7.8 MB/s eta 0:00:01
#    --------------------- ------------------ 3.6/6.9 MB 8.0 MB/s eta 0:00:01
# ...

# %%
# !pip install comet_ml
# Out:
# ...
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# ...
#      ---------------------------------------- 0.0/101.5 kB ? eta -:--:--
#      -------------- ---------------------- 41.0/101.5 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 101.5/101.5 kB 1.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#    ---------------------------------------- 0.0/709.7 kB ? eta -:--:--
#    -------- ------------------------------- 153.6/709.7 kB 3.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 409.6/709.7 kB 5.1 MB/s eta 0:00:01
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-385-gb968b2d7 Python-3.12.0 torch-2.2.1+cpu CPU
#
# ...

# %%
# !pip install torch==2.5.1 torchvision==0.20.1 torchaudio===2.5.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# ...
#   Using cached torch-2.5.1-cp312-cp312-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached torchvision-0.20.1-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# ...
#    ---------------------------------------- 0.0/203.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/203.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/203.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/203.0 MB 393.8 kB/s eta 0:08:36
#    ---------------------------------------- 0.1/203.0 MB 819.2 kB/s eta 0:04:08
#    ---------------------------------------- 0.3/203.0 MB 1.4 MB/s eta 0:02:22
#    ---------------------------------------- 0.4/203.0 MB 1.9 MB/s eta 0:01:49
#    ---------------------------------------- 0.8/203.0 MB 3.1 MB/s eta 0:01:07
#    ---------------------------------------- 1.0/203.0 MB 3.3 MB/s eta 0:01:01
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp3/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\Afiq/.cache\torch\hub\master.zip
# YOLOv5  2024-11-20 Python-3.12.0 torch-2.2.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7061368 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# Updating files:  99% (673/677)
# Updating files: 100% (677/677)
# Updating files: 100% (677/677), done.

# %%
# !pip uninstall torch torchvision torchaudio
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# ^C
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
import torch
print(torch.cuda.is_available())  # Should return True
print(torch.version.cuda)         # Verify the CUDA version
print(torch.backends.cudnn.enabled)  # Should return True if cuDNN is enabled
# Out:
# False
# None
# True

# %%
from glob import glob

# Replace with paths from your dataset.yml
train_images = glob("D:/CodingStorage/Python/FlaskFyp2Detection/train")
val_images = glob("./val")

print(f"Training images: {len(train_images)}")
print(f"Validation images: {len(val_images)}")
# Out:
# Training images: 1
# Validation images: 1

# %%
from ultralytics import YOLO

# Load model
model = YOLO("yolo11n.pt")  # Ensure the file exists and is valid

# Train the model
model.train(
    data="dataset_test.yml",  # Ensure the dataset.yml file is correct
    batch=8,
    epochs=100,
    imgsz=640,
    workers=2,  # Use more workers if possible
    device="cpu"  # Change to 'cuda' if GPU is available
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.49 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.47  Python-3.9.20 torch-2.5.1+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# ...

# %%
import ultralytics

model = ultralytics.YOLO("last.pt")

model.export(format="tflite", save_dir="/")
# Out:
# Ultralytics 8.3.49  Python-3.9.20 torch-2.5.1+cu118 CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# YOLO11n summary (fused): 238 layers, 2,585,857 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'last.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 23, 8400) (5.2 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
# WARNING:tensorflow:From d:\CodingStorage\flutter\yolodetection\.conda\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.43...
# ONNX: export success  2.5s, saved as 'last.onnx' (10.2 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.20.0...
# TensorFlow SavedModel: export success  36.0s, saved as 'last_saved_model' (25.7 MB)
#
# ...
